# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
T = np.array([-156, -110, -105, -100, -95, -90, -85, -80, -77, -74, -71, -68, -65, -62, -59, -56, -53, -48, 25, 127])
R = np.array([1031.4, 1046.9, 1043.7, 1030.05, 1002.8, 979.8, 949.9, 909.6, 879.3, 832.2, 713.6, 416.1, 307.7, 285.7, 282.1, 281.7, 281.7, 279.5, 265.2, 266.7])

# %%
plt.plot(T)

# %%
with open('transport.pickle','wb') as f:
    pickle.dump({'T':T,'R':R},f)

# %%
with open('transport.pickle','rb') as f:
    rs=pickle.load(f)

# %%
rs
# Out:
# {'T': array([-156, -110, -105, -100,  -95,  -90,  -85,  -80,  -77,  -74,  -71,
#          -68,  -65,  -62,  -59,  -56,  -53,  -48,   25,  127]),
#  'R': array([1031.4 , 1046.9 , 1043.7 , 1030.05, 1002.8 ,  979.8 ,  949.9 ,
#          909.6 ,  879.3 ,  832.2 ,  713.6 ,  416.1 ,  307.7 ,  285.7 ,
#          282.1 ,  281.7 ,  281.7 ,  279.5 ,  265.2 ,  266.7 ])}
